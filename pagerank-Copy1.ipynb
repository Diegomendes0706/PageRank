# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import scipy as scipy

# %%
grafo = {}
grafo['1'] = ["4"]
grafo['2'] = ['1', '3']
grafo['3'] = ['4']
grafo['4'] = ['2']
G = nx.DiGraph(grafo)
nx.draw(G, pos, with_labels = True, node_color="red")

# %%
def pagerank(grafo, d):
    n = len(grafo)
    E = np.ones((n, n), dtype=int)
    M = nx.graphmatrix(G)
    print(M)
pagerank(G, 0.85)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       4     M = nx.graphmatrix(G)
#       5     print(M)
# ----> 6 pagerank(G, 0.85)
#
# Cell In[44], line 4, in pagerank(grafo, d)
#       2 n = len(grafo)
#       3 E = np.ones((n, n), dtype=int)
# ----> 4 M = nx.graphmatrix(G)
#       5 print(M)
#
# TypeError: 'module' object is not callable

# %%
len(grafo)
G.nodes
# Out:
# NodeView(('1', '2', '3', '4'))
